# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# Get the movielens matrix
movielens = np.zeros((943,1682))
f = open("./ml-100k/u.data", "r")
for i in f.readlines():
    string = i.split()
    movielens[int(string[0])-1][int(string[1])-1] = int(string[2])
f.close()

# Get the no. of entries filled on each column
nz0 = np.count_nonzero(movielens, axis=0)

# Check for and delete the columns that there is only one or even no entry filled
while True:
  allOne = False
  notAllTwo1 = []
  allTwo = True

  # Check for each column
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      notAllTwo1.append(j)
      allTwo = False
    
  # Start the division of the uncompleted R if all rows and columns have at least 2 entries filled
  if allTwo == True:
    break

  # Delete the columns that have only one or even no entry filled
  movielens = np.delete(movielens,notAllTwo1,axis=1)

  # Get the number of entries filled on each row and columns
  nz0 = np.count_nonzero(movielens, axis=0)

  # Check whether each of column has only one or even no entry filled 
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      allOne = True
    else:
      allOne = False
      break
  
  # Give up to filling the matrix R if each row and column has only one or even no entry filled
  if allOne == True:
    break

# Save the matrix in a csv file
np.savetxt('movielens.csv', movielens, delimiter=',')
    
if allOne == True:
  print("The matrix cannot be filled because each row and column has only one or even no entry filled")
else:
  # Divide into 2 nearly equally distributed matrices that are mutually exclusive
  allOne = False
  while allOne == False:
    
    # copy the movielens into movielens2 first
    movielens2 = movielens.copy()
    movielens1 = np.zeros(movielens.shape)

    
    # randomly assign the entries to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in range(movielens.shape[1]):
      i = np.random.choice(movielens[:, j].nonzero()[0], size=int(np.count_nonzero(movielens[:, j])/2), replace=False)
      movielens2[i,j] = 0
      movielens1[i,j] = movielens[i,j]
    
    # get the number of non-missing entries for each column
    nz1 = np.count_nonzero(movielens1, axis=0)
    nz2 = np.count_nonzero(movielens2, axis=0)
    
    # calculate the difference of the numbers of non-zero entries for each column between the 2 matrices
    diff_row = nz2 - nz1
    
    # randomly pick half of the columns whose difference is 1 
    ran = np.random.choice(diff_row.nonzero()[0], size=int(np.count_nonzero(diff_row)/2), replace=False)

    # reassign one of the entries for each of those columns to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in ran:
      if(diff_row[j] == 1):  
        i = np.random.choice(movielens2[:, j].nonzero()[0], size=1, replace=False)
        movielens1[i,j] = movielens2[i,j]
        movielens2[i,j] = 0
    
    allOne = True
    
    # check whether each row and column of both movielens1 and movielens2 has at least one non-missing entries
    for j in range(movielens.shape[1]):
      if(not movielens1[:,j].any()):
        allOne = False
        break
      if(not movielens2[:,j].any()):
        allOne = False
        break
        
  # get the position of non-missing entries in movielens1 and movielens2
  X2, Y2 = movielens2.nonzero()
  X1, Y1 = movielens1.nonzero()
    
  # get the number of non-missing entries in movielens1 and movielens2
  nz3 = np.count_nonzero(movielens2)
  nz4 = np.count_nonzero(movielens1)
    
  # Save the matrices in a csv file 
  np.savetxt('movielens1.csv', movielens1, delimiter=',')
  np.savetxt('movielens2.csv', movielens2, delimiter=',')

  # No. of versions of P1
  L = 5

  # No. of rank
  R = 2

  # Regularization
  reg = 1
    
  # Get the mse at the nth iteration
  iter_array = [1, 2, 5, 10, 20]
    
  for l in range(L):
    
    print("Set %d" %(l+1))
    print()
    
    # Initialize User and Item Latents and Biases
    temp = np.random.sample((movielens.shape[0],R))
    P1 = np.copy(temp)
    Q1 = np.zeros((movielens.shape[1],R))
    P2 = np.copy(temp)
    Q2 = np.zeros((movielens.shape[1],R))
    n = 0
    
    # No. of iterations
    T = 20
    
    line_iter = []
    line_mae2 = []
    line_mse2 = []
    line_mae1 = []
    line_mse1 = []
    line_learning_rate = []
    
    start = time.time()
    
    # Complete R by using ALS
    for t in range(T):
    
      # Do the matrix completion by ALS based on the non-missing entries in movielens1 and movielens2
      for j in range(movielens1.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens1.shape[0]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P1[i,l1] * P1[i,l2]
            B += movielens1[i,j] * P1[i,:]
        Q1[j,:] = np.linalg.solve(A,B)
        
      for i in range(movielens1.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens1.shape[1]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q1[j,l1] * Q1[j,l2]
            C += movielens1[i,j] * Q1[j,:]
        P1[i,:] = np.linalg.solve(A,C)
        
      for j in range(movielens2.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens2.shape[0]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P2[i,l1] * P2[i,l2]
            B += movielens2[i,j] * P2[i,:]
        Q2[j,:] = np.linalg.solve(A,B)
    
      for i in range(movielens2.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens2.shape[1]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q2[j,l1] * Q2[j,l2]
            C += movielens2[i,j] * Q2[j,:]
        P2[i,:] = np.linalg.solve(A,C)
        
      # calculate the MSE and MAE
      cost1 = 0
      cost2 = 0
      for x, y in zip(X2, Y2):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P1[x,r] * Q1[y,r]
        cost1 += abs(movielens2[x, y] - predicted_entry)
        cost2 += pow(movielens2[x, y] - predicted_entry,2)
      mae2 = cost1 / nz3 / 4
      mse2 = cost2 / nz3
      
      cost1 = 0
      cost2 = 0
      for x, y in zip(X1, Y1):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P2[x,r] * Q2[y,r]
        cost1 += abs(movielens1[x, y] - predicted_entry)
        cost2 += pow(movielens1[x, y] - predicted_entry,2)
      mae1 = cost1 / nz4 / 4
      mse1 = cost2 / nz4
    
      # Record the iterations done and the current MSE
      line_iter.append(t+1)
      line_mae2.append(mae2)
      line_mse2.append(mse2)
      line_mae1.append(mae1)
      line_mse1.append(mse1)
        
      print("Iteration: %d" %(t+1))
      if (t+1) == iter_array[n]:
        print("MAE of movielens2: %.4f" %mae2)
        print("MSE of movielens2: %.4f" %mse2)
        print("MAE of movielens1: %.4f" %mae1)
        print("MSE of movielens1: %.4f" %mse1)
        n += 1
        
      print()
    
    end = time.time()
    
    # Update the predicted movielens
    predicted1 = np.zeros(movielens1.shape)
    for i in range(movielens1.shape[0]):
      for j in range(movielens1.shape[1]):
        for r in range(R):
          predicted1[i,j] += P1[i,r] * Q1[j,r]
        
    predicted2 = np.zeros(movielens2.shape)
    for i in range(movielens2.shape[0]):
      for j in range(movielens2.shape[1]):
        for r in range(R):
          predicted2[i,j] += P2[i,r] * Q2[j,r]
        
    # Save the predicted matrices in a csv file 
    np.savetxt('movielens_ALS_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_2_%d.csv' %(l+1), predicted2, delimiter=',')
    
    print("Time used: %f"%(end-start))
    print()
    
    # Do the constraint
    for i in range(predicted1.shape[0]):
      for j in range(predicted1.shape[1]):
        if predicted1[i,j] < 1.5:
            predicted1[i,j] = 1
        elif (predicted1[i,j] >= 1.5 and predicted1[i,j] < 5.5):
            predicted1[i,j] = int(round(predicted1[i,j]))
        else:
            predicted1[i,j] = 5
    
    for i in range(predicted2.shape[0]):
      for j in range(predicted2.shape[1]):
        if predicted2[i,j] < 1.5:
            predicted2[i,j] = 1
        elif (predicted2[i,j] >= 1.5 and predicted2[i,j] < 5.5):
            predicted2[i,j] = int(round(predicted2[i,j]))
        else:
            predicted2[i,j] = 5
    
    plt.plot(line_iter, line_mae2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mae1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE1 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE1 vs iterations by ALS")
    plt.show()
    
    cost1 = 0
    cost2 = 0
    for x, y in zip(X2, Y2):
      cost1 += abs(movielens2[x, y] - predicted1[x, y])
      cost2 += pow(movielens2[x, y] - predicted1[x, y],2)
    mae2 = cost1 / nz3 / 4
    mse2 = cost2 / nz3
      
    cost1 = 0
    cost2 = 0
    for x, y in zip(X1, Y1):
      cost1 += abs(movielens1[x, y] - predicted2[x, y])
      cost2 += pow(movielens1[x, y] - predicted2[x, y],2)
    mae1 = cost1 / nz4 / 4
    mse1 = cost2 / nz4
    
    print("After constraining,")
    print("MAE of movielens2: %.4f" %mae2)  
    print("MSE of movielens2: %.4f" %mse2)
    print("MAE of movielens1: %.4f" %mae1)
    print("MSE of movielens1: %.4f" %mse1)
    print()
    
    
    np.savetxt('movielens_ALS_constraint_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_constraint_2_%d.csv' %(l+1), predicted2, delimiter=',')
# Out:
# Set 1
#
# Iteration: 1
# MAE of movielens2: 0.1987
# MSE of movielens2: 1.0272
# MAE of movielens1: 0.1980
# MSE of movielens1: 1.0165
#
# Iteration: 2
# MAE of movielens2: 0.1951
# MSE of movielens2: 0.9997
# MAE of movielens1: 0.1955
# MSE of movielens1: 1.0014
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1952
# MSE of movielens2: 1.0054
# MAE of movielens1: 0.1959
# MSE of movielens1: 1.0185
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1933
# MSE of movielens2: 0.9836
# MAE of movielens1: 0.1914
# MSE of movielens1: 0.9721
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1871
# MSE of movielens2: 0.9175
# MAE of movielens1: 0.1852
# MSE of movielens1: 0.9018
#
# Time used: 127.172499
# After constraining,
# MAE of movielens2: 0.1767
# MSE of movielens2: 0.9960
# MAE of movielens1: 0.1747
# MSE of movielens1: 0.9751
#
# Set 2
#
# Iteration: 1
# MAE of movielens2: 0.1979
# MSE of movielens2: 1.0231
# MAE of movielens1: 0.1983
# MSE of movielens1: 1.0176
#
# Iteration: 2
# MAE of movielens2: 0.1951
# MSE of movielens2: 1.0020
# MAE of movielens1: 0.1955
# MSE of movielens1: 1.0017
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1906
# MSE of movielens2: 0.9614
# MAE of movielens1: 0.1918
# MSE of movielens1: 0.9743
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1868
# MSE of movielens2: 0.9193
# MAE of movielens1: 0.1863
# MSE of movielens1: 0.9144
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1861
# MSE of movielens2: 0.9093
# MAE of movielens1: 0.1852
# MSE of movielens1: 0.9013
#
# Time used: 137.370834
# After constraining,
# MAE of movielens2: 0.1758
# MSE of movielens2: 0.9863
# MAE of movielens1: 0.1747
# MSE of movielens1: 0.9762
#
# Set 3
#
# Iteration: 1
# MAE of movielens2: 0.1975
# MSE of movielens2: 1.0176
# MAE of movielens1: 0.1972
# MSE of movielens1: 1.0127
#
# Iteration: 2
# MAE of movielens2: 0.1954
# MSE of movielens2: 1.0032
# MAE of movielens1: 0.1951
# MSE of movielens1: 1.0009
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1955
# MSE of movielens2: 1.0130
# MAE of movielens1: 0.1960
# MSE of movielens1: 1.0158
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1884
# MSE of movielens2: 0.9385
# MAE of movielens1: 0.1905
# MSE of movielens1: 0.9628
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1865
# MSE of movielens2: 0.9129
# MAE of movielens1: 0.1854
# MSE of movielens1: 0.9039
#
# Time used: 141.903010
# After constraining,
# MAE of movielens2: 0.1761
# MSE of movielens2: 0.9898
# MAE of movielens1: 0.1747
# MSE of movielens1: 0.9780
#
# Set 4
#
# Iteration: 1
# MAE of movielens2: 0.1970
# MSE of movielens2: 1.0131
# MAE of movielens1: 0.1977
# MSE of movielens1: 1.0146
#
# Iteration: 2
# MAE of movielens2: 0.1937
# MSE of movielens2: 0.9890
# MAE of movielens1: 0.1935
# MSE of movielens1: 0.9800
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1898
# MSE of movielens2: 0.9541
# MAE of movielens1: 0.1880
# MSE of movielens1: 0.9329
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1873
# MSE of movielens2: 0.9247
# MAE of movielens1: 0.1862
# MSE of movielens1: 0.9141
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1862
# MSE of movielens2: 0.9098
# MAE of movielens1: 0.1852
# MSE of movielens1: 0.9020
#
# Time used: 150.056261
# After constraining,
# MAE of movielens2: 0.1758
# MSE of movielens2: 0.9871
# MAE of movielens1: 0.1748
# MSE of movielens1: 0.9766
#
# Set 5
#
# Iteration: 1
# MAE of movielens2: 0.1971
# MSE of movielens2: 1.0150
# MAE of movielens1: 0.1975
# MSE of movielens1: 1.0113
#
# Iteration: 2
# MAE of movielens2: 0.1938
# MSE of movielens2: 0.9897
# MAE of movielens1: 0.1930
# MSE of movielens1: 0.9753
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1898
# MSE of movielens2: 0.9553
# MAE of movielens1: 0.1881
# MSE of movielens1: 0.9308
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1870
# MSE of movielens2: 0.9226
# MAE of movielens1: 0.1862
# MSE of movielens1: 0.9148
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1863
# MSE of movielens2: 0.9111
# MAE of movielens1: 0.1852
# MSE of movielens1: 0.9025
#
# Time used: 134.958737
# After constraining,
# MAE of movielens2: 0.1759
# MSE of movielens2: 0.9882
# MAE of movielens1: 0.1747
# MSE of movielens1: 0.9767

# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# Get the movielens matrix
movielens = np.zeros((943,1682))
f = open("./ml-100k/u.data", "r")
for i in f.readlines():
    string = i.split()
    movielens[int(string[0])-1][int(string[1])-1] = int(string[2])
f.close()

# Get the no. of entries filled on each column
nz0 = np.count_nonzero(movielens, axis=0)

# Check for and delete the columns that there is only one or even no entry filled
while True:
  allOne = False
  notAllTwo1 = []
  allTwo = True

  # Check for each column
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      notAllTwo1.append(j)
      allTwo = False
    
  # Start the division of the uncompleted R if all rows and columns have at least 2 entries filled
  if allTwo == True:
    break

  # Delete the columns that have only one or even no entry filled
  movielens = np.delete(movielens,notAllTwo1,axis=1)

  # Get the number of entries filled on each row and columns
  nz0 = np.count_nonzero(movielens, axis=0)

  # Check whether each of column has only one or even no entry filled 
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      allOne = True
    else:
      allOne = False
      break
  
  # Give up to filling the matrix R if each row and column has only one or even no entry filled
  if allOne == True:
    break

# Save the matrix in a csv file
np.savetxt('movielens.csv', movielens, delimiter=',')
    
if allOne == True:
  print("The matrix cannot be filled because each row and column has only one or even no entry filled")
else:
  # Divide into 2 nearly equally distributed matrices that are mutually exclusive
  allOne = False
  while allOne == False:
    
    # copy the movielens into movielens2 first
    movielens2 = movielens.copy()
    movielens1 = np.zeros(movielens.shape)

    
    # randomly assign the entries to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in range(movielens.shape[1]):
      i = np.random.choice(movielens[:, j].nonzero()[0], size=int(np.count_nonzero(movielens[:, j])/2), replace=False)
      movielens2[i,j] = 0
      movielens1[i,j] = movielens[i,j]
    
    # get the number of non-missing entries for each column
    nz1 = np.count_nonzero(movielens1, axis=0)
    nz2 = np.count_nonzero(movielens2, axis=0)
    
    # calculate the difference of the numbers of non-zero entries for each column between the 2 matrices
    diff_row = nz2 - nz1
    
    # randomly pick half of the columns whose difference is 1 
    ran = np.random.choice(diff_row.nonzero()[0], size=int(np.count_nonzero(diff_row)/2), replace=False)

    # reassign one of the entries for each of those columns to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in ran:
      if(diff_row[j] == 1):  
        i = np.random.choice(movielens2[:, j].nonzero()[0], size=1, replace=False)
        movielens1[i,j] = movielens2[i,j]
        movielens2[i,j] = 0
    
    allOne = True
    
    # check whether each row and column of both movielens1 and movielens2 has at least one non-missing entries
    for j in range(movielens.shape[1]):
      if(not movielens1[:,j].any()):
        allOne = False
        break
      if(not movielens2[:,j].any()):
        allOne = False
        break
        
  # get the position of non-missing entries in movielens1 and movielens2
  X2, Y2 = movielens2.nonzero()
  X1, Y1 = movielens1.nonzero()
    
  # get the number of non-missing entries in movielens1 and movielens2
  nz3 = np.count_nonzero(movielens2)
  nz4 = np.count_nonzero(movielens1)
    
  # Save the matrices in a csv file 
  np.savetxt('movielens1.csv', movielens1, delimiter=',')
  np.savetxt('movielens2.csv', movielens2, delimiter=',')

  # No. of versions of P1
  L = 5

  # No. of rank
  R = 2

  # Regularization
  reg = 0
    
  # Get the mse at the nth iteration
  iter_array = [1, 2, 5, 10, 20]
    
  for l in range(L):
    
    print("Set %d" %(l+1))
    print()
    
    # Initialize User and Item Latents and Biases
    temp = np.random.sample((movielens.shape[0],R))
    P1 = np.copy(temp)
    Q1 = np.zeros((movielens.shape[1],R))
    P2 = np.copy(temp)
    Q2 = np.zeros((movielens.shape[1],R))
    n = 0
    
    # No. of iterations
    T = 20
    
    line_iter = []
    line_mae2 = []
    line_mse2 = []
    line_mae1 = []
    line_mse1 = []
    line_learning_rate = []
    
    start = time.time()
    
    # Complete R by using ALS
    for t in range(T):
      
      # Do the matrix completion by ALS based on the non-missing entries in movielens1 and movielens2
      for j in range(movielens1.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens1.shape[0]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P1[i,l1] * P1[i,l2]
            B += movielens1[i,j] * P1[i,:]
        Q1[j,:] = np.linalg.solve(A,B)
        
      for i in range(movielens1.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens1.shape[1]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q1[j,l1] * Q1[j,l2]
            C += movielens1[i,j] * Q1[j,:]
        P1[i,:] = np.linalg.solve(A,C)
        
      for j in range(movielens2.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens2.shape[0]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P2[i,l1] * P2[i,l2]
            B += movielens2[i,j] * P2[i,:]
        Q2[j,:] = np.linalg.solve(A,B)
    
      for i in range(movielens2.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens2.shape[1]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q2[j,l1] * Q2[j,l2]
            C += movielens2[i,j] * Q2[j,:]
        P2[i,:] = np.linalg.solve(A,C)
        
      # calculate the MSE and MAE
      cost1 = 0
      cost2 = 0
      for x, y in zip(X2, Y2):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P1[x,r] * Q1[y,r]
        cost1 += abs(movielens2[x, y] - predicted_entry)
        cost2 += pow(movielens2[x, y] - predicted_entry,2)
      mae2 = cost1 / nz3 / 4
      mse2 = cost2 / nz3
      
      cost1 = 0
      cost2 = 0
      for x, y in zip(X1, Y1):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P2[x,r] * Q2[y,r]
        cost1 += abs(movielens1[x, y] - predicted_entry)
        cost2 += pow(movielens1[x, y] - predicted_entry,2)
      mae1 = cost1 / nz4 / 4
      mse1 = cost2 / nz4
    
      # Record the iterations done and the current MSE
      line_iter.append(t+1)
      line_mae2.append(mae2)
      line_mse2.append(mse2)
      line_mae1.append(mae1)
      line_mse1.append(mse1)
        
      print("Iteration: %d" %(t+1))
      if (t+1) == iter_array[n]:
        print("MAE of movielens2: %.4f" %mae2)
        print("MSE of movielens2: %.4f" %mse2)
        print("MAE of movielens1: %.4f" %mae1)
        print("MSE of movielens1: %.4f" %mse1)
        n += 1
        
      print()
    
    end = time.time()
    
    # Update the predicted movielens
    predicted1 = np.zeros(movielens1.shape)
    for i in range(movielens1.shape[0]):
      for j in range(movielens1.shape[1]):
        for r in range(R):
          predicted1[i,j] += P1[i,r] * Q1[j,r]
        
    predicted2 = np.zeros(movielens2.shape)
    for i in range(movielens2.shape[0]):
      for j in range(movielens2.shape[1]):
        for r in range(R):
          predicted2[i,j] += P2[i,r] * Q2[j,r]
        
    # Save the predicted matrices in a csv file 
    np.savetxt('movielens_ALS_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_2_%d.csv' %(l+1), predicted2, delimiter=',')
    
    print("Time used: %f"%(end-start))
    print()
    
    # Do the constraint
    for i in range(predicted1.shape[0]):
      for j in range(predicted1.shape[1]):
        if predicted1[i,j] < 1.5:
            predicted1[i,j] = 1
        elif (predicted1[i,j] >= 1.5 and predicted1[i,j] < 5.5):
            predicted1[i,j] = int(round(predicted1[i,j]))
        else:
            predicted1[i,j] = 5
    
    for i in range(predicted2.shape[0]):
      for j in range(predicted2.shape[1]):
        if predicted2[i,j] < 1.5:
            predicted2[i,j] = 1
        elif (predicted2[i,j] >= 1.5 and predicted2[i,j] < 5.5):
            predicted2[i,j] = int(round(predicted2[i,j]))
        else:
            predicted2[i,j] = 5
    
    plt.plot(line_iter, line_mae2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mae1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE1 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE1 vs iterations by ALS")
    plt.show()
    
    cost1 = 0
    cost2 = 0
    for x, y in zip(X2, Y2):
      cost1 += abs(movielens2[x, y] - predicted1[x, y])
      cost2 += pow(movielens2[x, y] - predicted1[x, y],2)
    mae2 = cost1 / nz3 / 4
    mse2 = cost2 / nz3
      
    cost1 = 0
    cost2 = 0
    for x, y in zip(X1, Y1):
      cost1 += abs(movielens1[x, y] - predicted2[x, y])
      cost2 += pow(movielens1[x, y] - predicted2[x, y],2)
    mae1 = cost1 / nz4 / 4
    mse1 = cost2 / nz4
    
    print("After constraining,")
    print("MAE of movielens2: %.4f" %mae2)  
    print("MSE of movielens2: %.4f" %mse2)
    print("MAE of movielens1: %.4f" %mae1)
    print("MSE of movielens1: %.4f" %mse1)
    print()
    
    
    np.savetxt('movielens_ALS_constraint_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_constraint_2_%d.csv' %(l+1), predicted2, delimiter=',')
# Out:
# Set 1
#
# Iteration: 1
# MAE of movielens2: 0.2204
# MSE of movielens2: 15.6173
# MAE of movielens1: 0.2298
# MSE of movielens1: 29.1305
#
# Iteration: 2
# MAE of movielens2: 0.2083
# MSE of movielens2: 14.4644
# MAE of movielens1: 0.2672
# MSE of movielens1: 2380.3344
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.2110
# MSE of movielens2: 13.4000
# MAE of movielens1: 0.2610
# MSE of movielens1: 1991.5425
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.2136
# MSE of movielens2: 16.0536
# MAE of movielens1: 0.2625
# MSE of movielens1: 1680.2589
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.2364
# MSE of movielens2: 90.2273
# MAE of movielens1: 6.7815
# MSE of movielens1: 33735393.6988
#
# Time used: 146.705444
# After constraining,
# MAE of movielens2: 0.1811
# MSE of movielens2: 1.0403
# MAE of movielens1: 0.1869
# MSE of movielens1: 1.1023
#
# Set 2
#
# Iteration: 1
# MAE of movielens2: 0.2255
# MSE of movielens2: 30.4256
# MAE of movielens1: 0.2221
# MSE of movielens1: 9.7527
#
# Iteration: 2
# MAE of movielens2: 0.7224
# MSE of movielens2: 104308.8457
# MAE of movielens1: 0.2503
# MSE of movielens1: 121.4998
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.7060
# MSE of movielens2: 96091.6614
# MAE of movielens1: 0.2174
# MSE of movielens1: 15.6244
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.7080
# MSE of movielens2: 90876.0954
# MAE of movielens1: 0.2329
# MSE of movielens1: 67.0999
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.6983
# MSE of movielens2: 85516.6641
# MAE of movielens1: 0.2508
# MSE of movielens1: 121.2237
#
# Time used: 140.731683
# After constraining,
# MAE of movielens2: 0.1835
# MSE of movielens2: 1.0696
# MAE of movielens1: 0.1866
# MSE of movielens1: 1.1056
#
# Set 3
#
# Iteration: 1
# MAE of movielens2: 0.2153
# MSE of movielens2: 8.0801
# MAE of movielens1: 0.2161
# MSE of movielens1: 7.7989
#
# Iteration: 2
# MAE of movielens2: 0.2023
# MSE of movielens2: 2.0278
# MAE of movielens1: 0.2028
# MSE of movielens1: 1.9186
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.2077
# MSE of movielens2: 5.4644
# MAE of movielens1: 0.2073
# MSE of movielens1: 2.6535
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.2194
# MSE of movielens2: 22.2835
# MAE of movielens1: 0.2122
# MSE of movielens1: 6.9897
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.2604
# MSE of movielens2: 192.2988
# MAE of movielens1: 0.2447
# MSE of movielens1: 68.2124
#
# Time used: 151.685744
# After constraining,
# MAE of movielens2: 0.1803
# MSE of movielens2: 1.0411
# MAE of movielens1: 0.1833
# MSE of movielens1: 1.0744
#
# Set 4
#
# Iteration: 1
# MAE of movielens2: 0.2071
# MSE of movielens2: 1.9710
# MAE of movielens1: 0.2092
# MSE of movielens1: 3.3357
#
# Iteration: 2
# MAE of movielens2: 0.2017
# MSE of movielens2: 2.9024
# MAE of movielens1: 0.2112
# MSE of movielens1: 21.8298
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.2076
# MSE of movielens2: 3.9282
# MAE of movielens1: 0.2192
# MSE of movielens1: 23.2539
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.2137
# MSE of movielens2: 9.1025
# MAE of movielens1: 0.2246
# MSE of movielens1: 32.9919
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.2327
# MSE of movielens2: 41.5666
# MAE of movielens1: 0.2435
# MSE of movielens1: 71.0700
#
# Time used: 134.457829
# After constraining,
# MAE of movielens2: 0.1810
# MSE of movielens2: 1.0467
# MAE of movielens1: 0.1832
# MSE of movielens1: 1.0704
#
# Set 5
#
# Iteration: 1
# MAE of movielens2: 0.2285
# MSE of movielens2: 20.7594
# MAE of movielens1: 0.2886
# MSE of movielens1: 2260.2230
#
# Iteration: 2
# MAE of movielens2: 0.2132
# MSE of movielens2: 9.3487
# MAE of movielens1: 0.2775
# MSE of movielens1: 2546.2281
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.2040
# MSE of movielens2: 2.2672
# MAE of movielens1: 0.2929
# MSE of movielens1: 2643.2976
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.2107
# MSE of movielens2: 8.5724
# MAE of movielens1: 0.3222
# MSE of movielens1: 2416.1235
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.2239
# MSE of movielens2: 18.6615
# MAE of movielens1: 0.3754
# MSE of movielens1: 1499.6966
#
# Time used: 145.950724
# After constraining,
# MAE of movielens2: 0.1801
# MSE of movielens2: 1.0382
# MAE of movielens1: 0.1812
# MSE of movielens1: 1.0473

# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# Get the movielens matrix
movielens = np.zeros((943,1682))
f = open("./ml-100k/u.data", "r")
for i in f.readlines():
    string = i.split()
    movielens[int(string[0])-1][int(string[1])-1] = int(string[2])
f.close()

# Get the no. of entries filled on each column
nz0 = np.count_nonzero(movielens, axis=0)

# Check for and delete the columns that there is only one or even no entry filled
while True:
  allOne = False
  notAllTwo1 = []
  allTwo = True

  # Check for each column
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      notAllTwo1.append(j)
      allTwo = False
    
  # Start the division of the uncompleted R if all rows and columns have at least 2 entries filled
  if allTwo == True:
    break

  # Delete the columns that have only one or even no entry filled
  movielens = np.delete(movielens,notAllTwo1,axis=1)

  # Get the number of entries filled on each row and columns
  nz0 = np.count_nonzero(movielens, axis=0)

  # Check whether each of column has only one or even no entry filled 
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      allOne = True
    else:
      allOne = False
      break
  
  # Give up to filling the matrix R if each row and column has only one or even no entry filled
  if allOne == True:
    break

# Save the matrix in a csv file
np.savetxt('movielens.csv', movielens, delimiter=',')
    
if allOne == True:
  print("The matrix cannot be filled because each row and column has only one or even no entry filled")
else:
  # Divide into 2 nearly equally distributed matrices that are mutually exclusive
  allOne = False
  while allOne == False:
    
    # copy the movielens into movielens2 first
    movielens2 = movielens.copy()
    movielens1 = np.zeros(movielens.shape)

    
    # randomly assign the entries to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in range(movielens.shape[1]):
      i = np.random.choice(movielens[:, j].nonzero()[0], size=int(np.count_nonzero(movielens[:, j])/2), replace=False)
      movielens2[i,j] = 0
      movielens1[i,j] = movielens[i,j]
    
    # get the number of non-missing entries for each column
    nz1 = np.count_nonzero(movielens1, axis=0)
    nz2 = np.count_nonzero(movielens2, axis=0)
    
    # calculate the difference of the numbers of non-zero entries for each column between the 2 matrices
    diff_row = nz2 - nz1
    
    # randomly pick half of the columns whose difference is 1 
    ran = np.random.choice(diff_row.nonzero()[0], size=int(np.count_nonzero(diff_row)/2), replace=False)

    # reassign one of the entries for each of those columns to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in ran:
      if(diff_row[j] == 1):  
        i = np.random.choice(movielens2[:, j].nonzero()[0], size=1, replace=False)
        movielens1[i,j] = movielens2[i,j]
        movielens2[i,j] = 0
    
    allOne = True
    
    # check whether each row and column of both movielens1 and movielens2 has at least one non-missing entries
    for j in range(movielens.shape[1]):
      if(not movielens1[:,j].any()):
        allOne = False
        break
      if(not movielens2[:,j].any()):
        allOne = False
        break
        
  # get the position of non-missing entries in movielens1 and movielens2
  X2, Y2 = movielens2.nonzero()
  X1, Y1 = movielens1.nonzero()
    
  # get the number of non-missing entries in movielens1 and movielens2
  nz3 = np.count_nonzero(movielens2)
  nz4 = np.count_nonzero(movielens1)
    
  # Save the matrices in a csv file 
  np.savetxt('movielens1.csv', movielens1, delimiter=',')
  np.savetxt('movielens2.csv', movielens2, delimiter=',')

  # No. of versions of P1
  L = 5

  # No. of rank
  R = 2

  # Regularization
  reg = 5
    
  # Get the mse at the nth iteration
  iter_array = [1, 2, 5, 10, 20]
    
  for l in range(L):
    
    print("Set %d" %(l+1))
    print()
    
    # Initialize User and Item Latents and Biases
    temp = np.random.sample((movielens.shape[0],R))
    P1 = np.copy(temp)
    Q1 = np.zeros((movielens.shape[1],R))
    P2 = np.copy(temp)
    Q2 = np.zeros((movielens.shape[1],R))
    n = 0
    
    # No. of iterations
    T = 20
    
    line_iter = []
    line_mae2 = []
    line_mse2 = []
    line_mae1 = []
    line_mse1 = []
    line_learning_rate = []
    
    start = time.time()
    
    # Complete R by using ALS
    for t in range(T):
      
      # Do the matrix completion by ALS based on the non-missing entries in movielens1 and movielens2
      for j in range(movielens1.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens1.shape[0]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P1[i,l1] * P1[i,l2]
            B += movielens1[i,j] * P1[i,:]
        Q1[j,:] = np.linalg.solve(A,B)
        
      for i in range(movielens1.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens1.shape[1]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q1[j,l1] * Q1[j,l2]
            C += movielens1[i,j] * Q1[j,:]
        P1[i,:] = np.linalg.solve(A,C)
        
      for j in range(movielens2.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens2.shape[0]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P2[i,l1] * P2[i,l2]
            B += movielens2[i,j] * P2[i,:]
        Q2[j,:] = np.linalg.solve(A,B)
    
      for i in range(movielens2.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens2.shape[1]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q2[j,l1] * Q2[j,l2]
            C += movielens2[i,j] * Q2[j,:]
        P2[i,:] = np.linalg.solve(A,C)
        
      # calculate the MSE and MAE
      cost1 = 0
      cost2 = 0
      for x, y in zip(X2, Y2):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P1[x,r] * Q1[y,r]
        cost1 += abs(movielens2[x, y] - predicted_entry)
        cost2 += pow(movielens2[x, y] - predicted_entry,2)
      mae2 = cost1 / nz3 / 4
      mse2 = cost2 / nz3
      
      cost1 = 0
      cost2 = 0
      for x, y in zip(X1, Y1):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P2[x,r] * Q2[y,r]
        cost1 += abs(movielens1[x, y] - predicted_entry)
        cost2 += pow(movielens1[x, y] - predicted_entry,2)
      mae1 = cost1 / nz4 / 4
      mse1 = cost2 / nz4
    
      # Record the iterations done and the current MSE
      line_iter.append(t+1)
      line_mae2.append(mae2)
      line_mse2.append(mse2)
      line_mae1.append(mae1)
      line_mse1.append(mse1)
        
      print("Iteration: %d" %(t+1))
      if (t+1) == iter_array[n]:
        print("MAE of movielens2: %.4f" %mae2)
        print("MSE of movielens2: %.4f" %mse2)
        print("MAE of movielens1: %.4f" %mae1)
        print("MSE of movielens1: %.4f" %mse1)
        n += 1
        
      print()
    
    end = time.time()
    
    # Update the predicted movielens
    predicted1 = np.zeros(movielens1.shape)
    for i in range(movielens1.shape[0]):
      for j in range(movielens1.shape[1]):
        for r in range(R):
          predicted1[i,j] += P1[i,r] * Q1[j,r]
        
    predicted2 = np.zeros(movielens2.shape)
    for i in range(movielens2.shape[0]):
      for j in range(movielens2.shape[1]):
        for r in range(R):
          predicted2[i,j] += P2[i,r] * Q2[j,r]
        
    # Save the predicted matrices in a csv file 
    np.savetxt('movielens_ALS_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_2_%d.csv' %(l+1), predicted2, delimiter=',')
    
    print("Time used: %f"%(end-start))
    print()
    
    # Do the constraint
    for i in range(predicted1.shape[0]):
      for j in range(predicted1.shape[1]):
        if predicted1[i,j] < 1.5:
            predicted1[i,j] = 1
        elif (predicted1[i,j] >= 1.5 and predicted1[i,j] < 5.5):
            predicted1[i,j] = int(round(predicted1[i,j]))
        else:
            predicted1[i,j] = 5
    
    for i in range(predicted2.shape[0]):
      for j in range(predicted2.shape[1]):
        if predicted2[i,j] < 1.5:
            predicted2[i,j] = 1
        elif (predicted2[i,j] >= 1.5 and predicted2[i,j] < 5.5):
            predicted2[i,j] = int(round(predicted2[i,j]))
        else:
            predicted2[i,j] = 5
    
    plt.plot(line_iter, line_mae2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mae1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE1 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE1 vs iterations by ALS")
    plt.show()
    
    cost1 = 0
    cost2 = 0
    for x, y in zip(X2, Y2):
      cost1 += abs(movielens2[x, y] - predicted1[x, y])
      cost2 += pow(movielens2[x, y] - predicted1[x, y],2)
    mae2 = cost1 / nz3 / 4
    mse2 = cost2 / nz3
      
    cost1 = 0
    cost2 = 0
    for x, y in zip(X1, Y1):
      cost1 += abs(movielens1[x, y] - predicted2[x, y])
      cost2 += pow(movielens1[x, y] - predicted2[x, y],2)
    mae1 = cost1 / nz4 / 4
    mse1 = cost2 / nz4
    
    print("After constraining,")
    print("MAE of movielens2: %.4f" %mae2)  
    print("MSE of movielens2: %.4f" %mse2)
    print("MAE of movielens1: %.4f" %mae1)
    print("MSE of movielens1: %.4f" %mse1)
    print()
    
    
    np.savetxt('movielens_ALS_constraint_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_constraint_2_%d.csv' %(l+1), predicted2, delimiter=',')
# Out:
# Set 1
#
# Iteration: 1
# MAE of movielens2: 0.2120
# MSE of movielens2: 1.2008
# MAE of movielens1: 0.2114
# MSE of movielens1: 1.1983
#
# Iteration: 2
# MAE of movielens2: 0.2042
# MSE of movielens2: 1.1058
# MAE of movielens1: 0.2048
# MSE of movielens1: 1.1119
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1943
# MSE of movielens2: 0.9954
# MAE of movielens1: 0.1965
# MSE of movielens1: 1.0147
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1905
# MSE of movielens2: 0.9483
# MAE of movielens1: 0.1907
# MSE of movielens1: 0.9482
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1900
# MSE of movielens2: 0.9358
# MAE of movielens1: 0.1898
# MSE of movielens1: 0.9329
#
# Time used: 126.248758
# After constraining,
# MAE of movielens2: 0.1797
# MSE of movielens2: 1.0106
# MAE of movielens1: 0.1800
# MSE of movielens1: 1.0123
#
# Set 2
#
# Iteration: 1
# MAE of movielens2: 0.2123
# MSE of movielens2: 1.2017
# MAE of movielens1: 0.2125
# MSE of movielens1: 1.2065
#
# Iteration: 2
# MAE of movielens2: 0.2033
# MSE of movielens2: 1.0974
# MAE of movielens1: 0.2043
# MSE of movielens1: 1.1105
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1936
# MSE of movielens2: 0.9941
# MAE of movielens1: 0.1936
# MSE of movielens1: 0.9911
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1906
# MSE of movielens2: 0.9521
# MAE of movielens1: 0.1902
# MSE of movielens1: 0.9470
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1900
# MSE of movielens2: 0.9365
# MAE of movielens1: 0.1898
# MSE of movielens1: 0.9333
#
# Time used: 129.422985
# After constraining,
# MAE of movielens2: 0.1796
# MSE of movielens2: 1.0107
# MAE of movielens1: 0.1797
# MSE of movielens1: 1.0109
#
# Set 3
#
# Iteration: 1
# MAE of movielens2: 0.2117
# MSE of movielens2: 1.1948
# MAE of movielens1: 0.2114
# MSE of movielens1: 1.1933
#
# Iteration: 2
# MAE of movielens2: 0.2040
# MSE of movielens2: 1.1036
# MAE of movielens1: 0.2040
# MSE of movielens1: 1.1062
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1943
# MSE of movielens2: 0.9931
# MAE of movielens1: 0.1956
# MSE of movielens1: 1.0069
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1906
# MSE of movielens2: 0.9479
# MAE of movielens1: 0.1908
# MSE of movielens1: 0.9484
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1900
# MSE of movielens2: 0.9356
# MAE of movielens1: 0.1899
# MSE of movielens1: 0.9328
#
# Time used: 142.239971
# After constraining,
# MAE of movielens2: 0.1796
# MSE of movielens2: 1.0095
# MAE of movielens1: 0.1800
# MSE of movielens1: 1.0126
#
# Set 4
#
# Iteration: 1
# MAE of movielens2: 0.2118
# MSE of movielens2: 1.1994
# MAE of movielens1: 0.2116
# MSE of movielens1: 1.1982
#
# Iteration: 2
# MAE of movielens2: 0.2009
# MSE of movielens2: 1.0769
# MAE of movielens1: 0.2009
# MSE of movielens1: 1.0779
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1931
# MSE of movielens2: 0.9877
# MAE of movielens1: 0.1930
# MSE of movielens1: 0.9856
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1905
# MSE of movielens2: 0.9492
# MAE of movielens1: 0.1903
# MSE of movielens1: 0.9463
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1900
# MSE of movielens2: 0.9361
# MAE of movielens1: 0.1898
# MSE of movielens1: 0.9331
#
# Time used: 144.818229
# After constraining,
# MAE of movielens2: 0.1796
# MSE of movielens2: 1.0107
# MAE of movielens1: 0.1799
# MSE of movielens1: 1.0113
#
# Set 5
#
# Iteration: 1
# MAE of movielens2: 0.2134
# MSE of movielens2: 1.2145
# MAE of movielens1: 0.2127
# MSE of movielens1: 1.2073
#
# Iteration: 2
# MAE of movielens2: 0.2056
# MSE of movielens2: 1.1214
# MAE of movielens1: 0.2053
# MSE of movielens1: 1.1193
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.2001
# MSE of movielens2: 1.0506
# MAE of movielens1: 0.1980
# MSE of movielens1: 1.0366
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1932
# MSE of movielens2: 0.9714
# MAE of movielens1: 0.1907
# MSE of movielens1: 0.9532
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1901
# MSE of movielens2: 0.9358
# MAE of movielens1: 0.1898
# MSE of movielens1: 0.9336
#
# Time used: 140.922225
# After constraining,
# MAE of movielens2: 0.1796
# MSE of movielens2: 1.0103
# MAE of movielens1: 0.1797
# MSE of movielens1: 1.0113

# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# Get the movielens matrix
movielens = np.zeros((943,1682))
f = open("./ml-100k/u.data", "r")
for i in f.readlines():
    string = i.split()
    movielens[int(string[0])-1][int(string[1])-1] = int(string[2])
f.close()

# Get the no. of entries filled on each column
nz0 = np.count_nonzero(movielens, axis=0)

# Check for and delete the columns that there is only one or even no entry filled
while True:
  allOne = False
  notAllTwo1 = []
  allTwo = True

  # Check for each column
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      notAllTwo1.append(j)
      allTwo = False
    
  # Start the division of the uncompleted R if all rows and columns have at least 2 entries filled
  if allTwo == True:
    break

  # Delete the columns that have only one or even no entry filled
  movielens = np.delete(movielens,notAllTwo1,axis=1)

  # Get the number of entries filled on each row and columns
  nz0 = np.count_nonzero(movielens, axis=0)

  # Check whether each of column has only one or even no entry filled 
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      allOne = True
    else:
      allOne = False
      break
  
  # Give up to filling the matrix R if each row and column has only one or even no entry filled
  if allOne == True:
    break

# Save the matrix in a csv file
np.savetxt('movielens.csv', movielens, delimiter=',')
    
if allOne == True:
  print("The matrix cannot be filled because each row and column has only one or even no entry filled")
else:
  # Divide into 2 nearly equally distributed matrices that are mutually exclusive
  allOne = False
  while allOne == False:
    
    # copy the movielens into movielens2 first
    movielens2 = movielens.copy()
    movielens1 = np.zeros(movielens.shape)

    
    # randomly assign the entries to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in range(movielens.shape[1]):
      i = np.random.choice(movielens[:, j].nonzero()[0], size=int(np.count_nonzero(movielens[:, j])/2), replace=False)
      movielens2[i,j] = 0
      movielens1[i,j] = movielens[i,j]
    
    # get the number of non-missing entries for each column
    nz1 = np.count_nonzero(movielens1, axis=0)
    nz2 = np.count_nonzero(movielens2, axis=0)
    
    # calculate the difference of the numbers of non-zero entries for each column between the 2 matrices
    diff_row = nz2 - nz1
    
    # randomly pick half of the columns whose difference is 1 
    ran = np.random.choice(diff_row.nonzero()[0], size=int(np.count_nonzero(diff_row)/2), replace=False)

    # reassign one of the entries for each of those columns to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in ran:
      if(diff_row[j] == 1):  
        i = np.random.choice(movielens2[:, j].nonzero()[0], size=1, replace=False)
        movielens1[i,j] = movielens2[i,j]
        movielens2[i,j] = 0
    
    allOne = True
    
    # check whether each row and column of both movielens1 and movielens2 has at least one non-missing entries
    for j in range(movielens.shape[1]):
      if(not movielens1[:,j].any()):
        allOne = False
        break
      if(not movielens2[:,j].any()):
        allOne = False
        break
        
  # get the position of non-missing entries in movielens1 and movielens2
  X2, Y2 = movielens2.nonzero()
  X1, Y1 = movielens1.nonzero()
    
  # get the number of non-missing entries in movielens1 and movielens2
  nz3 = np.count_nonzero(movielens2)
  nz4 = np.count_nonzero(movielens1)
    
  # Save the matrices in a csv file 
  np.savetxt('movielens1.csv', movielens1, delimiter=',')
  np.savetxt('movielens2.csv', movielens2, delimiter=',')

  # No. of versions of P1
  L = 5

  # No. of rank
  R = 2

  # Regularization
  reg = 0.5
    
  # Get the mse at the nth iteration
  iter_array = [1, 2, 5, 10, 20]
    
  for l in range(L):
    
    print("Set %d" %(l+1))
    print()
    
    # Initialize User and Item Latents and Biases
    temp = np.random.sample((movielens.shape[0],R))
    P1 = np.copy(temp)
    Q1 = np.zeros((movielens.shape[1],R))
    P2 = np.copy(temp)
    Q2 = np.zeros((movielens.shape[1],R))
    n = 0
    
    # No. of iterations
    T = 20
    
    line_iter = []
    line_mae2 = []
    line_mse2 = []
    line_mae1 = []
    line_mse1 = []
    line_learning_rate = []
    
    start = time.time()
    
    # Complete R by using ALS
    for t in range(T):
      
      # Do the matrix completion by ALS based on the non-missing entries in movielens1 and movielens2
      for j in range(movielens1.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens1.shape[0]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P1[i,l1] * P1[i,l2]
            B += movielens1[i,j] * P1[i,:]
        Q1[j,:] = np.linalg.solve(A,B)
        
      for i in range(movielens1.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens1.shape[1]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q1[j,l1] * Q1[j,l2]
            C += movielens1[i,j] * Q1[j,:]
        P1[i,:] = np.linalg.solve(A,C)
        
      for j in range(movielens2.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens2.shape[0]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P2[i,l1] * P2[i,l2]
            B += movielens2[i,j] * P2[i,:]
        Q2[j,:] = np.linalg.solve(A,B)
    
      for i in range(movielens2.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens2.shape[1]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q2[j,l1] * Q2[j,l2]
            C += movielens2[i,j] * Q2[j,:]
        P2[i,:] = np.linalg.solve(A,C)
        
      # calculate the MSE and MAE
      cost1 = 0
      cost2 = 0
      for x, y in zip(X2, Y2):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P1[x,r] * Q1[y,r]
        cost1 += abs(movielens2[x, y] - predicted_entry)
        cost2 += pow(movielens2[x, y] - predicted_entry,2)
      mae2 = cost1 / nz3 / 4
      mse2 = cost2 / nz3
      
      cost1 = 0
      cost2 = 0
      for x, y in zip(X1, Y1):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P2[x,r] * Q2[y,r]
        cost1 += abs(movielens1[x, y] - predicted_entry)
        cost2 += pow(movielens1[x, y] - predicted_entry,2)
      mae1 = cost1 / nz4 / 4
      mse1 = cost2 / nz4
    
      # Record the iterations done and the current MSE
      line_iter.append(t+1)
      line_mae2.append(mae2)
      line_mse2.append(mse2)
      line_mae1.append(mae1)
      line_mse1.append(mse1)
        
      print("Iteration: %d" %(t+1))
      if (t+1) == iter_array[n]:
        print("MAE of movielens2: %.4f" %mae2)
        print("MSE of movielens2: %.4f" %mse2)
        print("MAE of movielens1: %.4f" %mae1)
        print("MSE of movielens1: %.4f" %mse1)
        n += 1
        
      print()
    
    end = time.time()
    
    # Update the predicted movielens
    predicted1 = np.zeros(movielens1.shape)
    for i in range(movielens1.shape[0]):
      for j in range(movielens1.shape[1]):
        for r in range(R):
          predicted1[i,j] += P1[i,r] * Q1[j,r]
        
    predicted2 = np.zeros(movielens2.shape)
    for i in range(movielens2.shape[0]):
      for j in range(movielens2.shape[1]):
        for r in range(R):
          predicted2[i,j] += P2[i,r] * Q2[j,r]
        
    # Save the predicted matrices in a csv file 
    np.savetxt('movielens_ALS_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_2_%d.csv' %(l+1), predicted2, delimiter=',')
    
    print("Time used: %f"%(end-start))
    print()
    
    # Do the constraint
    for i in range(predicted1.shape[0]):
      for j in range(predicted1.shape[1]):
        if predicted1[i,j] < 1.5:
            predicted1[i,j] = 1
        elif (predicted1[i,j] >= 1.5 and predicted1[i,j] < 5.5):
            predicted1[i,j] = int(round(predicted1[i,j]))
        else:
            predicted1[i,j] = 5
    
    for i in range(predicted2.shape[0]):
      for j in range(predicted2.shape[1]):
        if predicted2[i,j] < 1.5:
            predicted2[i,j] = 1
        elif (predicted2[i,j] >= 1.5 and predicted2[i,j] < 5.5):
            predicted2[i,j] = int(round(predicted2[i,j]))
        else:
            predicted2[i,j] = 5
    
    plt.plot(line_iter, line_mae2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mae1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE1 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE1 vs iterations by ALS")
    plt.show()
    
    cost1 = 0
    cost2 = 0
    for x, y in zip(X2, Y2):
      cost1 += abs(movielens2[x, y] - predicted1[x, y])
      cost2 += pow(movielens2[x, y] - predicted1[x, y],2)
    mae2 = cost1 / nz3 / 4
    mse2 = cost2 / nz3
      
    cost1 = 0
    cost2 = 0
    for x, y in zip(X1, Y1):
      cost1 += abs(movielens1[x, y] - predicted2[x, y])
      cost2 += pow(movielens1[x, y] - predicted2[x, y],2)
    mae1 = cost1 / nz4 / 4
    mse1 = cost2 / nz4
    
    print("After constraining,")
    print("MAE of movielens2: %.4f" %mae2)  
    print("MSE of movielens2: %.4f" %mse2)
    print("MAE of movielens1: %.4f" %mae1)
    print("MSE of movielens1: %.4f" %mse1)
    print()
    
    
    np.savetxt('movielens_ALS_constraint_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_constraint_2_%d.csv' %(l+1), predicted2, delimiter=',')
# Out:
# Set 1
#
# Iteration: 1
# MAE of movielens2: 0.1956
# MSE of movielens2: 0.9875
# MAE of movielens1: 0.1967
# MSE of movielens1: 1.0024
#
# Iteration: 2
# MAE of movielens2: 0.1924
# MSE of movielens2: 0.9632
# MAE of movielens1: 0.1933
# MSE of movielens1: 0.9779
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1897
# MSE of movielens2: 0.9466
# MAE of movielens1: 0.1894
# MSE of movielens1: 0.9497
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1866
# MSE of movielens2: 0.9187
# MAE of movielens1: 0.1875
# MSE of movielens1: 0.9305
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1862
# MSE of movielens2: 0.9131
# MAE of movielens1: 0.1873
# MSE of movielens1: 0.9269
#
# Time used: 127.928786
# After constraining,
# MAE of movielens2: 0.1757
# MSE of movielens2: 0.9896
# MAE of movielens1: 0.1765
# MSE of movielens1: 0.9955
#
# Set 2
#
# Iteration: 1
# MAE of movielens2: 0.1969
# MSE of movielens2: 1.0023
# MAE of movielens1: 0.1967
# MSE of movielens1: 1.0027
#
# Iteration: 2
# MAE of movielens2: 0.1940
# MSE of movielens2: 0.9798
# MAE of movielens1: 0.1951
# MSE of movielens1: 0.9977
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1942
# MSE of movielens2: 0.9904
# MAE of movielens1: 0.1964
# MSE of movielens1: 1.0264
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1885
# MSE of movielens2: 0.9387
# MAE of movielens1: 0.1944
# MSE of movielens1: 1.0109
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1865
# MSE of movielens2: 0.9173
# MAE of movielens1: 0.1875
# MSE of movielens1: 0.9303
#
# Time used: 137.911920
# After constraining,
# MAE of movielens2: 0.1762
# MSE of movielens2: 0.9944
# MAE of movielens1: 0.1769
# MSE of movielens1: 1.0006
#
# Set 3
#
# Iteration: 1
# MAE of movielens2: 0.1962
# MSE of movielens2: 0.9968
# MAE of movielens1: 0.1973
# MSE of movielens1: 1.0062
#
# Iteration: 2
# MAE of movielens2: 0.1940
# MSE of movielens2: 0.9858
# MAE of movielens1: 0.1941
# MSE of movielens1: 0.9861
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1946
# MSE of movielens2: 1.0015
# MAE of movielens1: 0.1916
# MSE of movielens1: 0.9721
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1904
# MSE of movielens2: 0.9604
# MAE of movielens1: 0.1881
# MSE of movielens1: 0.9366
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1866
# MSE of movielens2: 0.9164
# MAE of movielens1: 0.1875
# MSE of movielens1: 0.9292
#
# Time used: 143.722497
# After constraining,
# MAE of movielens2: 0.1762
# MSE of movielens2: 0.9915
# MAE of movielens1: 0.1768
# MSE of movielens1: 0.9988
#
# Set 4
#
# Iteration: 1
# MAE of movielens2: 0.1962
# MSE of movielens2: 0.9955
# MAE of movielens1: 0.1967
# MSE of movielens1: 1.0045
#
# Iteration: 2
# MAE of movielens2: 0.1945
# MSE of movielens2: 0.9925
# MAE of movielens1: 0.1947
# MSE of movielens1: 0.9938
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1958
# MSE of movielens2: 1.0183
# MAE of movielens1: 0.1950
# MSE of movielens1: 1.0057
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1942
# MSE of movielens2: 1.0016
# MAE of movielens1: 0.1884
# MSE of movielens1: 0.9394
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1871
# MSE of movielens2: 0.9246
# MAE of movielens1: 0.1874
# MSE of movielens1: 0.9296
#
# Time used: 142.941829
# After constraining,
# MAE of movielens2: 0.1765
# MSE of movielens2: 0.9959
# MAE of movielens1: 0.1764
# MSE of movielens1: 0.9971
#
# Set 5
#
# Iteration: 1
# MAE of movielens2: 0.1959
# MSE of movielens2: 0.9944
# MAE of movielens1: 0.1968
# MSE of movielens1: 1.0031
#
# Iteration: 2
# MAE of movielens2: 0.1935
# MSE of movielens2: 0.9806
# MAE of movielens1: 0.1940
# MSE of movielens1: 0.9846
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1947
# MSE of movielens2: 0.9998
# MAE of movielens1: 0.1944
# MSE of movielens1: 0.9986
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1934
# MSE of movielens2: 0.9933
# MAE of movielens1: 0.1887
# MSE of movielens1: 0.9446
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1871
# MSE of movielens2: 0.9255
# MAE of movielens1: 0.1874
# MSE of movielens1: 0.9307
#
# Time used: 144.134599
# After constraining,
# MAE of movielens2: 0.1762
# MSE of movielens2: 0.9969
# MAE of movielens1: 0.1765
# MSE of movielens1: 0.9970

# %%
import numpy as np
from matplotlib import pyplot as plt
import time

# Get the movielens matrix
movielens = np.zeros((943,1682))
f = open("./ml-100k/u.data", "r")
for i in f.readlines():
    string = i.split()
    movielens[int(string[0])-1][int(string[1])-1] = int(string[2])
f.close()

# Get the no. of entries filled on each column
nz0 = np.count_nonzero(movielens, axis=0)

# Check for and delete the columns that there is only one or even no entry filled
while True:
  allOne = False
  notAllTwo1 = []
  allTwo = True

  # Check for each column
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      notAllTwo1.append(j)
      allTwo = False
    
  # Start the division of the uncompleted R if all rows and columns have at least 2 entries filled
  if allTwo == True:
    break

  # Delete the columns that have only one or even no entry filled
  movielens = np.delete(movielens,notAllTwo1,axis=1)

  # Get the number of entries filled on each row and columns
  nz0 = np.count_nonzero(movielens, axis=0)

  # Check whether each of column has only one or even no entry filled 
  for j in range(nz0.shape[0]):
    if nz0[j] < 2:
      allOne = True
    else:
      allOne = False
      break
  
  # Give up to filling the matrix R if each row and column has only one or even no entry filled
  if allOne == True:
    break

# Save the matrix in a csv file
np.savetxt('movielens.csv', movielens, delimiter=',')
    
if allOne == True:
  print("The matrix cannot be filled because each row and column has only one or even no entry filled")
else:
  # Divide into 2 nearly equally distributed matrices that are mutually exclusive
  allOne = False
  while allOne == False:
    
    # copy the movielens into movielens2 first
    movielens2 = movielens.copy()
    movielens1 = np.zeros(movielens.shape)

    
    # randomly assign the entries to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in range(movielens.shape[1]):
      i = np.random.choice(movielens[:, j].nonzero()[0], size=int(np.count_nonzero(movielens[:, j])/2), replace=False)
      movielens2[i,j] = 0
      movielens1[i,j] = movielens[i,j]
    
    # get the number of non-missing entries for each column
    nz1 = np.count_nonzero(movielens1, axis=0)
    nz2 = np.count_nonzero(movielens2, axis=0)
    
    # calculate the difference of the numbers of non-zero entries for each column between the 2 matrices
    diff_row = nz2 - nz1
    
    # randomly pick half of the columns whose difference is 1 
    ran = np.random.choice(diff_row.nonzero()[0], size=int(np.count_nonzero(diff_row)/2), replace=False)

    # reassign one of the entries for each of those columns to movielens1 and the corresponding entries in movielens2 are set to 0
    for j in ran:
      if(diff_row[j] == 1):  
        i = np.random.choice(movielens2[:, j].nonzero()[0], size=1, replace=False)
        movielens1[i,j] = movielens2[i,j]
        movielens2[i,j] = 0
    
    allOne = True
    
    # check whether each row and column of both movielens1 and movielens2 has at least one non-missing entries
    for j in range(movielens.shape[1]):
      if(not movielens1[:,j].any()):
        allOne = False
        break
      if(not movielens2[:,j].any()):
        allOne = False
        break
        
  # get the position of non-missing entries in movielens1 and movielens2
  X2, Y2 = movielens2.nonzero()
  X1, Y1 = movielens1.nonzero()
    
  # get the number of non-missing entries in movielens1 and movielens2
  nz3 = np.count_nonzero(movielens2)
  nz4 = np.count_nonzero(movielens1)
    
  # Save the matrices in a csv file 
  np.savetxt('movielens1.csv', movielens1, delimiter=',')
  np.savetxt('movielens2.csv', movielens2, delimiter=',')

  # No. of versions of P1
  L = 5

  # No. of rank
  R = 2

  # Regularization
  reg = 2
    
  # Get the mse at the nth iteration
  iter_array = [1, 2, 5, 10, 20]
    
  for l in range(L):
    
    print("Set %d" %(l+1))
    print()
    
    # Initialize User and Item Latents and Biases
    temp = np.random.sample((movielens.shape[0],R))
    P1 = np.copy(temp)
    Q1 = np.zeros((movielens.shape[1],R))
    P2 = np.copy(temp)
    Q2 = np.zeros((movielens.shape[1],R))
    n = 0
    
    # No. of iterations
    T = 20
    
    line_iter = []
    line_mae2 = []
    line_mse2 = []
    line_mae1 = []
    line_mse1 = []
    line_learning_rate = []
    
    start = time.time()
    
    # Complete R by using ALS
    for t in range(T):
      
      # Do the matrix completion by ALS based on the non-missing entries in movielens1 and movielens2
      for j in range(movielens1.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens1.shape[0]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P1[i,l1] * P1[i,l2]
            B += movielens1[i,j] * P1[i,:]
        Q1[j,:] = np.linalg.solve(A,B)
        
      for i in range(movielens1.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens1.shape[1]):
          if movielens1[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q1[j,l1] * Q1[j,l2]
            C += movielens1[i,j] * Q1[j,:]
        P1[i,:] = np.linalg.solve(A,C)
        
      for j in range(movielens2.shape[1]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        B = np.zeros(R)
        for i in range(movielens2.shape[0]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += P2[i,l1] * P2[i,l2]
            B += movielens2[i,j] * P2[i,:]
        Q2[j,:] = np.linalg.solve(A,B)
    
      for i in range(movielens2.shape[0]):
        #A = np.zeros((R,R))
        A = reg * np.identity(R)
        C = np.zeros(R)
        for j in range(movielens2.shape[1]):
          if movielens2[i,j] != 0:
            for l1 in range(R):
              for l2 in range(R):
                A[l1,l2] += Q2[j,l1] * Q2[j,l2]
            C += movielens2[i,j] * Q2[j,:]
        P2[i,:] = np.linalg.solve(A,C)
        
      # calculate the MSE and MAE
      cost1 = 0
      cost2 = 0
      for x, y in zip(X2, Y2):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P1[x,r] * Q1[y,r]
        cost1 += abs(movielens2[x, y] - predicted_entry)
        cost2 += pow(movielens2[x, y] - predicted_entry,2)
      mae2 = cost1 / nz3 / 4
      mse2 = cost2 / nz3
      
      cost1 = 0
      cost2 = 0
      for x, y in zip(X1, Y1):
        predicted_entry = 0
        for r in range(R):
          predicted_entry += P2[x,r] * Q2[y,r]
        cost1 += abs(movielens1[x, y] - predicted_entry)
        cost2 += pow(movielens1[x, y] - predicted_entry,2)
      mae1 = cost1 / nz4 / 4
      mse1 = cost2 / nz4
    
      # Record the iterations done and the current MSE
      line_iter.append(t+1)
      line_mae2.append(mae2)
      line_mse2.append(mse2)
      line_mae1.append(mae1)
      line_mse1.append(mse1)
        
      print("Iteration: %d" %(t+1))
      if (t+1) == iter_array[n]:
        print("MAE of movielens2: %.4f" %mae2)
        print("MSE of movielens2: %.4f" %mse2)
        print("MAE of movielens1: %.4f" %mae1)
        print("MSE of movielens1: %.4f" %mse1)
        n += 1
        
      print()
    
    end = time.time()
    
    # Update the predicted movielens
    predicted1 = np.zeros(movielens1.shape)
    for i in range(movielens1.shape[0]):
      for j in range(movielens1.shape[1]):
        for r in range(R):
          predicted1[i,j] += P1[i,r] * Q1[j,r]
        
    predicted2 = np.zeros(movielens2.shape)
    for i in range(movielens2.shape[0]):
      for j in range(movielens2.shape[1]):
        for r in range(R):
          predicted2[i,j] += P2[i,r] * Q2[j,r]
        
    # Save the predicted matrices in a csv file 
    np.savetxt('movielens_ALS_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_2_%d.csv' %(l+1), predicted2, delimiter=',')
    
    print("Time used: %f"%(end-start))
    print()
    
    # Do the constraint
    for i in range(predicted1.shape[0]):
      for j in range(predicted1.shape[1]):
        if predicted1[i,j] < 1.5:
            predicted1[i,j] = 1
        elif (predicted1[i,j] >= 1.5 and predicted1[i,j] < 5.5):
            predicted1[i,j] = int(round(predicted1[i,j]))
        else:
            predicted1[i,j] = 5
    
    for i in range(predicted2.shape[0]):
      for j in range(predicted2.shape[1]):
        if predicted2[i,j] < 1.5:
            predicted2[i,j] = 1
        elif (predicted2[i,j] >= 1.5 and predicted2[i,j] < 5.5):
            predicted2[i,j] = int(round(predicted2[i,j]))
        else:
            predicted2[i,j] = 5
    
    plt.plot(line_iter, line_mae2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse2, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE2 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mae1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MAE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MAE1 vs iterations by ALS")
    plt.show()
    
    plt.plot(line_iter, line_mse1, color='blue', lw='1')
    plt.xlabel('iterations')  
    plt.ylabel('MSE')
    plt.xticks(np.arange(0, T+1, 1))
    plt.title("MSE1 vs iterations by ALS")
    plt.show()
    
    cost1 = 0
    cost2 = 0
    for x, y in zip(X2, Y2):
      cost1 += abs(movielens2[x, y] - predicted1[x, y])
      cost2 += pow(movielens2[x, y] - predicted1[x, y],2)
    mae2 = cost1 / nz3 / 4
    mse2 = cost2 / nz3
      
    cost1 = 0
    cost2 = 0
    for x, y in zip(X1, Y1):
      cost1 += abs(movielens1[x, y] - predicted2[x, y])
      cost2 += pow(movielens1[x, y] - predicted2[x, y],2)
    mae1 = cost1 / nz4 / 4
    mse1 = cost2 / nz4
    
    print("After constraining,")
    print("MAE of movielens2: %.4f" %mae2)  
    print("MSE of movielens2: %.4f" %mse2)
    print("MAE of movielens1: %.4f" %mae1)
    print("MSE of movielens1: %.4f" %mse1)
    print()
    
    
    np.savetxt('movielens_ALS_constraint_1_%d.csv' %(l+1), predicted1, delimiter=',')
    np.savetxt('movielens_ALS_constraint_2_%d.csv' %(l+1), predicted2, delimiter=',')
# Out:
# Set 1
#
# Iteration: 1
# MAE of movielens2: 0.2007
# MSE of movielens2: 1.0696
# MAE of movielens1: 0.2000
# MSE of movielens1: 1.0471
#
# Iteration: 2
# MAE of movielens2: 0.1976
# MSE of movielens2: 1.0410
# MAE of movielens1: 0.1972
# MSE of movielens1: 1.0205
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1967
# MSE of movielens2: 1.0368
# MAE of movielens1: 0.1968
# MSE of movielens1: 1.0218
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1899
# MSE of movielens2: 0.9621
# MAE of movielens1: 0.1948
# MSE of movielens1: 0.9975
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1858
# MSE of movielens2: 0.9115
# MAE of movielens1: 0.1866
# MSE of movielens1: 0.9078
#
# Time used: 132.685766
# After constraining,
# MAE of movielens2: 0.1752
# MSE of movielens2: 0.9866
# MAE of movielens1: 0.1762
# MSE of movielens1: 0.9807
#
# Set 2
#
# Iteration: 1
# MAE of movielens2: 0.2009
# MSE of movielens2: 1.0671
# MAE of movielens1: 0.2006
# MSE of movielens1: 1.0503
#
# Iteration: 2
# MAE of movielens2: 0.1976
# MSE of movielens2: 1.0357
# MAE of movielens1: 0.1967
# MSE of movielens1: 1.0161
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1948
# MSE of movielens2: 1.0138
# MAE of movielens1: 0.1907
# MSE of movielens1: 0.9626
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1880
# MSE of movielens2: 0.9375
# MAE of movielens1: 0.1874
# MSE of movielens1: 0.9209
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1857
# MSE of movielens2: 0.9089
# MAE of movielens1: 0.1861
# MSE of movielens1: 0.9014
#
# Time used: 147.966171
# After constraining,
# MAE of movielens2: 0.1753
# MSE of movielens2: 0.9849
# MAE of movielens1: 0.1758
# MSE of movielens1: 0.9775
#
# Set 3
#
# Iteration: 1
# MAE of movielens2: 0.2017
# MSE of movielens2: 1.0764
# MAE of movielens1: 0.2017
# MSE of movielens1: 1.0647
#
# Iteration: 2
# MAE of movielens2: 0.1973
# MSE of movielens2: 1.0381
# MAE of movielens1: 0.1979
# MSE of movielens1: 1.0311
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1912
# MSE of movielens2: 0.9796
# MAE of movielens1: 0.1951
# MSE of movielens1: 1.0046
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1875
# MSE of movielens2: 0.9356
# MAE of movielens1: 0.1885
# MSE of movielens1: 0.9324
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1859
# MSE of movielens2: 0.9117
# MAE of movielens1: 0.1862
# MSE of movielens1: 0.9029
#
# Time used: 154.637284
# After constraining,
# MAE of movielens2: 0.1754
# MSE of movielens2: 0.9857
# MAE of movielens1: 0.1759
# MSE of movielens1: 0.9790
#
# Set 4
#
# Iteration: 1
# MAE of movielens2: 0.2008
# MSE of movielens2: 1.0699
# MAE of movielens1: 0.2007
# MSE of movielens1: 1.0557
#
# Iteration: 2
# MAE of movielens2: 0.1975
# MSE of movielens2: 1.0379
# MAE of movielens1: 0.1977
# MSE of movielens1: 1.0272
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1907
# MSE of movielens2: 0.9713
# MAE of movielens1: 0.1963
# MSE of movielens1: 1.0145
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1873
# MSE of movielens2: 0.9312
# MAE of movielens1: 0.1890
# MSE of movielens1: 0.9341
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1858
# MSE of movielens2: 0.9094
# MAE of movielens1: 0.1862
# MSE of movielens1: 0.9012
#
# Time used: 133.825529
# After constraining,
# MAE of movielens2: 0.1753
# MSE of movielens2: 0.9853
# MAE of movielens1: 0.1760
# MSE of movielens1: 0.9778
#
# Set 5
#
# Iteration: 1
# MAE of movielens2: 0.2010
# MSE of movielens2: 1.0715
# MAE of movielens1: 0.2007
# MSE of movielens1: 1.0548
#
# Iteration: 2
# MAE of movielens2: 0.1960
# MSE of movielens2: 1.0243
# MAE of movielens1: 0.1966
# MSE of movielens1: 1.0120
#
# Iteration: 3
#
# Iteration: 4
#
# Iteration: 5
# MAE of movielens2: 0.1900
# MSE of movielens2: 0.9654
# MAE of movielens1: 0.1906
# MSE of movielens1: 0.9594
#
# Iteration: 6
#
# Iteration: 7
#
# Iteration: 8
#
# Iteration: 9
#
# Iteration: 10
# MAE of movielens2: 0.1875
# MSE of movielens2: 0.9338
# MAE of movielens1: 0.1874
# MSE of movielens1: 0.9210
#
# Iteration: 11
#
# Iteration: 12
#
# Iteration: 13
#
# Iteration: 14
#
# Iteration: 15
#
# Iteration: 16
#
# Iteration: 17
#
# Iteration: 18
#
# Iteration: 19
#
# Iteration: 20
# MAE of movielens2: 0.1859
# MSE of movielens2: 0.9106
# MAE of movielens1: 0.1860
# MSE of movielens1: 0.8994
#
# Time used: 146.996671
# After constraining,
# MAE of movielens2: 0.1755
# MSE of movielens2: 0.9869
# MAE of movielens1: 0.1757
# MSE of movielens1: 0.9771
